# %% [markdown]
# # 의사결정트리(ML_DecisionTree)

# %%
#@title 연봉 관련 데이터
# https://www.kaggle.com/datasets/ayessa/salary-prediction-classification
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
file_url = 'https://raw.githubusercontent.com/bigdata-young/bigdata_16th/main/data/salary.csv'

# %% [markdown]
# # 데이터 분석

# %%
df = pd.read_csv(file_url, skipinitialspace=True)

# %%
df.head()
# Out:
#    age  workclass     education  education-num      marital-status  \
# 0   25    Private          11th              7       Never-married
# 1   38    Private       HS-grad              9  Married-civ-spouse
# 2   28  Local-gov    Assoc-acdm             12  Married-civ-spouse
# 3   44    Private  Some-college             10  Married-civ-spouse
# 4   18        NaN  Some-college             10       Never-married
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                NaN    Own-child  White  Female             0             0
#
#    hours-per-week native-country  class
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  object
#  2   education       48842 non-null  object
#  3   education-num   48842 non-null  int64
#  4   marital-status  48842 non-null  object
#  5   occupation      46033 non-null  object
#  6   relationship    48842 non-null  object
#  7   race            48842 non-null  object
#  8   sex             48842 non-null  object
#  9   capital-gain    48842 non-null  int64
#  10  capital-loss    48842 non-null  int64
#  11  hours-per-week  48842 non-null  int64
#  12  native-country  47985 non-null  object
#  13  class           48842 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 5.2+ MB

# %%
# ahe : 연령
# education-num : 교육 년수
# capital-gain : 자산 증가량
# capital-loss : 자산 감소량
# hours-per-week : 주당 노동 시간
df.describe()
# Out:
#                 age  education-num  capital-gain  capital-loss  hours-per-week
# count  48842.000000   48842.000000  48842.000000  48842.000000    48842.000000
# mean      38.643585      10.078089   1079.067626     87.502314       40.422382
# std       13.710510       2.570973   7452.019058    403.004552       12.391444
# min       17.000000       1.000000      0.000000      0.000000        1.000000
# 25%       28.000000       9.000000      0.000000      0.000000       40.000000
# 50%       37.000000      10.000000      0.000000      0.000000       40.000000
# 75%       48.000000      12.000000      0.000000      0.000000       45.000000
# max       90.000000      16.000000  99999.000000   4356.000000       99.000000

# %%
# [범주형 변수]
# workclass : 고용 형태
# education : 학력
# marital-status : 결혼 상태
# occuption : 직업
# relationship : 가족관계
# race : 인종
# sex : 성별
# native-country : 출신국가
# class : 연봉 범위
df.describe(include=['O'])
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      46043     48842               48842           46033        48842
# unique         8        16                   7              14            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       33906     15784               22379            6172        19716
#
#          race    sex native-country  class
# count   48842  48842          47985  48842
# unique      5      2             41      2
# top     White   Male  United-States  <=50K
# freq    41762  32650          43832  37155

# %%
df.describe(include='all')
# Out:
#                  age workclass education  education-num      marital-status  \
# count   48842.000000     46043     48842   48842.000000               48842
# unique           NaN         8        16            NaN                   7
# top              NaN   Private   HS-grad            NaN  Married-civ-spouse
# freq             NaN     33906     15784            NaN               22379
# mean       38.643585       NaN       NaN      10.078089                 NaN
# std        13.710510       NaN       NaN       2.570973                 NaN
# min        17.000000       NaN       NaN       1.000000                 NaN
# 25%        28.000000       NaN       NaN       9.000000                 NaN
# 50%        37.000000       NaN       NaN      10.000000                 NaN
# 75%        48.000000       NaN       NaN      12.000000                 NaN
# max        90.000000       NaN       NaN      16.000000                 NaN
#
#             occupation relationship   race    sex  capital-gain  capital-loss  \
# count            46033        48842  48842  48842  48842.000000  48842.000000
# unique              14            6      5      2           NaN           NaN
# top     Prof-specialty      Husband  White   Male           NaN           NaN
# freq              6172        19716  41762  32650           NaN           NaN
# mean               NaN          NaN    NaN    NaN   1079.067626     87.502314
# std                NaN          NaN    NaN    NaN   7452.019058    403.004552
# min                NaN          NaN    NaN    NaN      0.000000      0.000000
# 25%                NaN          NaN    NaN    NaN      0.000000      0.000000
# 50%                NaN          NaN    NaN    NaN      0.000000      0.000000
# 75%                NaN          NaN    NaN    NaN      0.000000      0.000000
# max                NaN          NaN    NaN    NaN  99999.000000   4356.000000
#
#         hours-per-week native-country  class
# count     48842.000000          47985  48842
# unique             NaN             41      2
# top                NaN  United-States  <=50K
# freq               NaN          43832  37155
# mean         40.422382            NaN    NaN
# std          12.391444            NaN    NaN
# min           1.000000            NaN    NaN
# 25%          40.000000            NaN    NaN
# 50%          40.000000            NaN    NaN
# 75%          45.000000            NaN    NaN
# max          99.000000            NaN    NaN

# %% [markdown]
# # 데이터 전처리

# %%
df['class']
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 4        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: class, Length: 48842, dtype: object

# %%
df['class'].value_counts()
# Out:
# <=50K    37155
# >50K     11687
# Name: class, dtype: int64

# %%
df['class'] = df['class'].map({'<=50K': 0, '>50K': 1})
df['class']
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 48837    0
# 48838    1
# 48839    0
# 48840    0
# 48841    1
# Name: class, Length: 48842, dtype: int64

# %%
df['class'].value_counts()
# Out:
# 0    37155
# 1    11687
# Name: class, dtype: int64

# %%
for c in df.columns:
    print(c, df[c].dtype)
# Out:
# age int64
# workclass object
# education object
# education-num int64
# marital-status object
# occupation object
# relationship object
# race object
# sex object
# capital-gain int64
# capital-loss int64
# hours-per-week int64
# native-country object
# class int64

# %%
#
obj_list = []
for c in df.columns:
    if df[c].dtype == 'object':
        obj_list.append(c)
        # print(c, df[c].dtype)
print(obj_list)

# [ for c in df.columns]
obj_list2 = [c for c in df.columns if df[c].dtype == 'obgect']
print(obj_list2)
# Out:
# ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']
# []

# %%
for o in obj_list:
  print(o, df[o].nunique())
# Out:
# workclass 8
# education 16
# marital-status 7
# occupation 14
# relationship 6
# race 5
# sex 2
# native-country 41

# %%
# 1. 연속형 변수? <- 1, 2, 3...Group의 평균, 최빈값
# 2. drop?
# 3. dummies?
for o in obj_list:
  if df[o].nunique() > 10:
      print(o, df[o].nunique())
# Out:
# education 16
# occupation 14
# native-country 41

# %%
df.education.value_counts()
# Out:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
df['education-num']
# Out:
# 0         7
# 1         9
# 2        12
# 3        10
# 4        10
#          ..
# 48837    12
# 48838     9
# 48839     9
# 48840     9
# 48841     9
# Name: education-num, Length: 48842, dtype: int64

# %%
# 1~16 범위 같은값 확인
for n in range(1,17):
  # print(df[df['education=num']==n]['education'])
  # print(df[df['education=num']==n]['education'].nunique())
  print(df[df['education-num'] == n].education.nunique()==1)
# 같으니 'education', 'education-num' 둘중하나는 삭제 가능
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
# 'education' 컬럼 삭제
df.drop('education', axis=1, inplace=True)

# %%
# 데이터 이미 묶여있고, 직업이라는 데이터 특성상 연봉 큰 영향 예상
df['occupation'].value_counts()
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
df['native-country'].value_counts() # 미국이 가장 많다 나머지를?
# 1. 미국 vs 기타 : 1/0
# 2. 대륙별, 언어권별 -> 추가적인 기준을 만들어서
# Out:
# United-States                 43832
# Mexico                          951
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# Nicaragua                        49
# Peru                             46
# Ecuador                          45
# France                           38
# Ireland                          37
# Hong                             30
# Thailand                         30
# Cambodia                         28
# Trinadad&Tobago                  27
# Yugoslavia                       23
# Outlying-US(Guam-USVI-etc)       23
# Laos                             23
# Scotland                         21
# Honduras                         20
# Hungary                          19
# Holand-Netherlands                1
# Name: native-country, dtype: int64

# %%
# 국가별 고연봉자 평균을 내서 비교
# gropuby(묶고 싶은 열 이름) [특정한 열 이름].적용하고자하는 그룹함수() -> mean()
# 내림차순 정리 .sort_values(ascending=False)
df.groupby('native-country')['class'].mean().sort_values(ascending=False)
# Out:
# native-country
# France                        0.421053
# India                         0.410596
# Taiwan                        0.400000
# Iran                          0.372881
# England                       0.370079
# Greece                        0.367347
# Yugoslavia                    0.347826
# Japan                         0.347826
# Canada                        0.346154
# Italy                         0.323810
# Cambodia                      0.321429
# Hungary                       0.315789
# Ireland                       0.297297
# China                         0.295082
# Philippines                   0.288136
# Germany                       0.281553
# Hong                          0.266667
# Cuba                          0.246377
# United-States                 0.243977
# Poland                        0.195402
# Portugal                      0.179104
# South                         0.173913
# Thailand                      0.166667
# Scotland                      0.142857
# Jamaica                       0.141509
# Ecuador                       0.133333
# Haiti                         0.120000
# Puerto-Rico                   0.108696
# Honduras                      0.100000
# Peru                          0.086957
# Laos                          0.086957
# Vietnam                       0.081395
# Trinadad&Tobago               0.074074
# El-Salvador                   0.070968
# Nicaragua                     0.061224
# Mexico                        0.049422
# Dominican-Republic            0.048544
# Columbia                      0.047059
# Outlying-US(Guam-USVI-etc)    0.043478
# Guatemala                     0.034091
# Holand-Netherlands            0.000000
# Name: class, dtype: float64

# %%
# 프랑스 고연봉자 직업순
df[df['native-country']== 'France'].groupby('occupation')['class'].mean()
# Out:
# occupation
# Adm-clerical       0.666667
# Craft-repair       0.000000
# Exec-managerial    0.555556
# Farming-fishing    0.000000
# Other-service      0.000000
# Priv-house-serv    0.000000
# Prof-specialty     0.272727
# Protective-serv    1.000000
# Sales              1.000000
# Tech-support       0.750000
# Name: class, dtype: float64

# %%
# country 변수에  나라별 평균을 넣어준다
country_group = df.groupby('native-country')['class'].mean()
country_group
# Out:
# native-country
# Cambodia                      0.321429
# Canada                        0.346154
# China                         0.295082
# Columbia                      0.047059
# Cuba                          0.246377
# Dominican-Republic            0.048544
# Ecuador                       0.133333
# El-Salvador                   0.070968
# England                       0.370079
# France                        0.421053
# Germany                       0.281553
# Greece                        0.367347
# Guatemala                     0.034091
# Haiti                         0.120000
# Holand-Netherlands            0.000000
# Honduras                      0.100000
# Hong                          0.266667
# Hungary                       0.315789
# India                         0.410596
# Iran                          0.372881
# Ireland                       0.297297
# Italy                         0.323810
# Jamaica                       0.141509
# Japan                         0.347826
# Laos                          0.086957
# Mexico                        0.049422
# Nicaragua                     0.061224
# Outlying-US(Guam-USVI-etc)    0.043478
# Peru                          0.086957
# Philippines                   0.288136
# Poland                        0.195402
# Portugal                      0.179104
# Puerto-Rico                   0.108696
# Scotland                      0.142857
# South                         0.173913
# Taiwan                        0.400000
# Thailand                      0.166667
# Trinadad&Tobago               0.074074
# United-States                 0.243977
# Vietnam                       0.081395
# Yugoslavia                    0.347826
# Name: class, dtype: float64

# %%
country_group.index
# Out:
# Index(['Cambodia', 'Canada', 'China', 'Columbia', 'Cuba', 'Dominican-Republic',
#        'Ecuador', 'El-Salvador', 'England', 'France', 'Germany', 'Greece',
#        'Guatemala', 'Haiti', 'Holand-Netherlands', 'Honduras', 'Hong',
#        'Hungary', 'India', 'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan',
#        'Laos', 'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Puerto-Rico', 'Scotland', 'South',
#        'Taiwan', 'Thailand', 'Trinadad&Tobago', 'United-States', 'Vietnam',
#        'Yugoslavia'],
#       dtype='object', name='native-country')

# %%
country_group = country_group.reset_index()
country_group
# Out:
#                 native-country     class
# 0                     Cambodia  0.321429
# 1                       Canada  0.346154
# 2                        China  0.295082
# 3                     Columbia  0.047059
# 4                         Cuba  0.246377
# 5           Dominican-Republic  0.048544
# 6                      Ecuador  0.133333
# 7                  El-Salvador  0.070968
# 8                      England  0.370079
# 9                       France  0.421053
# 10                     Germany  0.281553
# 11                      Greece  0.367347
# 12                   Guatemala  0.034091
# 13                       Haiti  0.120000
# 14          Holand-Netherlands  0.000000
# 15                    Honduras  0.100000
# 16                        Hong  0.266667
# 17                     Hungary  0.315789
# 18                       India  0.410596
# 19                        Iran  0.372881
# 20                     Ireland  0.297297
# 21                       Italy  0.323810
# 22                     Jamaica  0.141509
# 23                       Japan  0.347826
# 24                        Laos  0.086957
# 25                      Mexico  0.049422
# 26                   Nicaragua  0.061224
# 27  Outlying-US(Guam-USVI-etc)  0.043478
# 28                        Peru  0.086957
# 29                 Philippines  0.288136
# 30                      Poland  0.195402
# 31                    Portugal  0.179104
# 32                 Puerto-Rico  0.108696
# 33                    Scotland  0.142857
# 34                       South  0.173913
# 35                      Taiwan  0.400000
# 36                    Thailand  0.166667
# 37             Trinadad&Tobago  0.074074
# 38               United-States  0.243977
# 39                     Vietnam  0.081395
# 40                  Yugoslavia  0.347826

# %%
# A.merge(B on=[기준이되는것]) A 왼쪽, B 오른쪽
# A라고 하는 쪽 결측치 있을 수 있음
# A를 모두 보존해주는 방향으로 -> B가 없어도 돼 (country_group.class) -> how=left
# index가 기본이여서 같으면 그냥 merge로 합치고 아니면 on으로 열(컬럼)을 지정해줘야함
# native-coutry? : 결측치...
df = df.merge(country_group, on = 'native-country', how='left')
df
# Out:
#        age     workclass  education-num      marital-status  \
# 0       25       Private              7       Never-married
# 1       38       Private              9  Married-civ-spouse
# 2       28     Local-gov             12  Married-civ-spouse
# 3       44       Private             10  Married-civ-spouse
# 4       18           NaN             10       Never-married
# ...    ...           ...            ...                 ...
# 48837   27       Private             12  Married-civ-spouse
# 48838   40       Private              9  Married-civ-spouse
# 48839   58       Private              9             Widowed
# 48840   22       Private              9       Never-married
# 48841   52  Self-emp-inc              9  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 0      Machine-op-inspct    Own-child  Black    Male             0
# 1        Farming-fishing      Husband  White    Male             0
# 2        Protective-serv      Husband  White    Male             0
# 3      Machine-op-inspct      Husband  Black    Male          7688
# 4                    NaN    Own-child  White  Female             0
# ...                  ...          ...    ...     ...           ...
# 48837       Tech-support         Wife  White  Female             0
# 48838  Machine-op-inspct      Husband  White    Male             0
# 48839       Adm-clerical    Unmarried  White  Female             0
# 48840       Adm-clerical    Own-child  White    Male             0
# 48841    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country  class_x   class_y
# 0                 0              40  United-States        0  0.243977
# 1                 0              50  United-States        0  0.243977
# 2                 0              40  United-States        1  0.243977
# 3                 0              40  United-States        1  0.243977
# 4                 0              30  United-States        0  0.243977
# ...             ...             ...            ...      ...       ...
# 48837             0              38  United-States        0  0.243977
# 48838             0              40  United-States        1  0.243977
# 48839             0              40  United-States        0  0.243977
# 48840             0              20  United-States        0  0.243977
# 48841             0              40  United-States        1  0.243977
#
# [48842 rows x 14 columns]

# %% [markdown]
# 1. 전처리 중입니다
# 2. 전처리 -> **범주형 변수** (drop? 연속형변수? dummies? 대체해?) / **결측치** /<br> (스케일링 -> 아웃라이어는 신경 X. 결정트리라서<br>
# 2-1. education : education-num -> drop<br>
# 2-2. occupation : 이미 묶여있고, 중요할 것 같아 -> dummies<br>
# 2-3. native-country : 출신국가들인데 어차피 결정트리니까 고연봉자 비율 정도로만 <br>처리해줘도 괜찮을듯하다.

# %%
df.drop('native-country', axis=1, inplace=True)
df
# Out:
#        age     workclass  education-num      marital-status  \
# 0       25       Private              7       Never-married
# 1       38       Private              9  Married-civ-spouse
# 2       28     Local-gov             12  Married-civ-spouse
# 3       44       Private             10  Married-civ-spouse
# 4       18           NaN             10       Never-married
# ...    ...           ...            ...                 ...
# 48837   27       Private             12  Married-civ-spouse
# 48838   40       Private              9  Married-civ-spouse
# 48839   58       Private              9             Widowed
# 48840   22       Private              9       Never-married
# 48841   52  Self-emp-inc              9  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 0      Machine-op-inspct    Own-child  Black    Male             0
# 1        Farming-fishing      Husband  White    Male             0
# 2        Protective-serv      Husband  White    Male             0
# 3      Machine-op-inspct      Husband  Black    Male          7688
# 4                    NaN    Own-child  White  Female             0
# ...                  ...          ...    ...     ...           ...
# 48837       Tech-support         Wife  White  Female             0
# 48838  Machine-op-inspct      Husband  White    Male             0
# 48839       Adm-clerical    Unmarried  White  Female             0
# 48840       Adm-clerical    Own-child  White    Male             0
# 48841    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week  class_x   class_y
# 0                 0              40        0  0.243977
# 1                 0              50        0  0.243977
# 2                 0              40        1  0.243977
# 3                 0              40        1  0.243977
# 4                 0              30        0  0.243977
# ...             ...             ...      ...       ...
# 48837             0              38        0  0.243977
# 48838             0              40        1  0.243977
# 48839             0              40        0  0.243977
# 48840             0              20        0  0.243977
# 48841             0              40        1  0.243977
#
# [48842 rows x 13 columns]

# %%
df = df.rename(columns={'class_x': 'class', 'class_y': 'native-country'})
df
# Out:
#        age     workclass  education-num      marital-status  \
# 0       25       Private              7       Never-married
# 1       38       Private              9  Married-civ-spouse
# 2       28     Local-gov             12  Married-civ-spouse
# 3       44       Private             10  Married-civ-spouse
# 4       18           NaN             10       Never-married
# ...    ...           ...            ...                 ...
# 48837   27       Private             12  Married-civ-spouse
# 48838   40       Private              9  Married-civ-spouse
# 48839   58       Private              9             Widowed
# 48840   22       Private              9       Never-married
# 48841   52  Self-emp-inc              9  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 0      Machine-op-inspct    Own-child  Black    Male             0
# 1        Farming-fishing      Husband  White    Male             0
# 2        Protective-serv      Husband  White    Male             0
# 3      Machine-op-inspct      Husband  Black    Male          7688
# 4                    NaN    Own-child  White  Female             0
# ...                  ...          ...    ...     ...           ...
# 48837       Tech-support         Wife  White  Female             0
# 48838  Machine-op-inspct      Husband  White    Male             0
# 48839       Adm-clerical    Unmarried  White  Female             0
# 48840       Adm-clerical    Own-child  White    Male             0
# 48841    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week  class  native-country
# 0                 0              40      0        0.243977
# 1                 0              50      0        0.243977
# 2                 0              40      1        0.243977
# 3                 0              40      1        0.243977
# 4                 0              30      0        0.243977
# ...             ...             ...    ...             ...
# 48837             0              38      0        0.243977
# 48838             0              40      1        0.243977
# 48839             0              40      0        0.243977
# 48840             0              20      0        0.243977
# 48841             0              40      1        0.243977
#
# [48842 rows x 13 columns]

# %%
df.isna().mean()
# Out:
# age               0.000000
# workclass         0.057307
# education-num     0.000000
# marital-status    0.000000
# occupation        0.057512
# relationship      0.000000
# race              0.000000
# sex               0.000000
# capital-gain      0.000000
# capital-loss      0.000000
# hours-per-week    0.000000
# class             0.000000
# native-country    0.017546
# dtype: float64

# %%
#@title 임의값 넣어주기
# df['native=country'].fillna(-99, inplace=True)
# df.isna().mean()
df['native-country'].fillna(-99, inplace=True)
df.isna().mean()
# Out:
# age               0.000000
# workclass         0.057307
# education-num     0.000000
# marital-status    0.000000
# occupation        0.057512
# relationship      0.000000
# race              0.000000
# sex               0.000000
# capital-gain      0.000000
# capital-loss      0.000000
# hours-per-week    0.000000
# class             0.000000
# native-country    0.000000
# dtype: float64

# %%
df['workclass'].fillna('Private', inplace=True)
df.isna().mean()
# Out:
# age               0.000000
# workclass         0.000000
# education-num     0.000000
# marital-status    0.000000
# occupation        0.057512
# relationship      0.000000
# race              0.000000
# sex               0.000000
# capital-gain      0.000000
# capital-loss      0.000000
# hours-per-week    0.000000
# class             0.000000
# native-country    0.000000
# dtype: float64

# %%
df['occupation'].value_counts()
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
# occupation 결측치 제거 확인
# df['occupation'].fillna('Unk', inplace=True)
df.isna().mean()
# Out:
# age               0.000000
# workclass         0.000000
# education-num     0.000000
# marital-status    0.000000
# occupation        0.057512
# relationship      0.000000
# race              0.000000
# sex               0.000000
# capital-gain      0.000000
# capital-loss      0.000000
# hours-per-week    0.000000
# class             0.000000
# native-country    0.000000
# dtype: float64

# %%
df2 = pd.get_dummies(df,drop_first=True)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48842 entries, 0 to 48841
# Data columns (total 43 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   48842 non-null  int64
#  1   education-num                         48842 non-null  int64
#  2   capital-gain                          48842 non-null  int64
#  3   capital-loss                          48842 non-null  int64
#  4   hours-per-week                        48842 non-null  int64
#  5   class                                 48842 non-null  int64
#  6   native-country                        48842 non-null  float64
#  7   workclass_Local-gov                   48842 non-null  uint8
#  8   workclass_Never-worked                48842 non-null  uint8
#  9   workclass_Private                     48842 non-null  uint8
#  10  workclass_Self-emp-inc                48842 non-null  uint8
#  11  workclass_Self-emp-not-inc            48842 non-null  uint8
#  12  workclass_State-gov                   48842 non-null  uint8
#  13  workclass_Without-pay                 48842 non-null  uint8
#  14  marital-status_Married-AF-spouse      48842 non-null  uint8
#  15  marital-status_Married-civ-spouse     48842 non-null  uint8
#  16  marital-status_Married-spouse-absent  48842 non-null  uint8
#  17  marital-status_Never-married          48842 non-null  uint8
#  18  marital-status_Separated              48842 non-null  uint8
#  19  marital-status_Widowed                48842 non-null  uint8
#  20  occupation_Armed-Forces               48842 non-null  uint8
#  21  occupation_Craft-repair               48842 non-null  uint8
#  22  occupation_Exec-managerial            48842 non-null  uint8
#  23  occupation_Farming-fishing            48842 non-null  uint8
#  24  occupation_Handlers-cleaners          48842 non-null  uint8
#  25  occupation_Machine-op-inspct          48842 non-null  uint8
#  26  occupation_Other-service              48842 non-null  uint8
#  27  occupation_Priv-house-serv            48842 non-null  uint8
#  28  occupation_Prof-specialty             48842 non-null  uint8
#  29  occupation_Protective-serv            48842 non-null  uint8
#  30  occupation_Sales                      48842 non-null  uint8
#  31  occupation_Tech-support               48842 non-null  uint8
#  32  occupation_Transport-moving           48842 non-null  uint8
#  33  relationship_Not-in-family            48842 non-null  uint8
#  34  relationship_Other-relative           48842 non-null  uint8
#  35  relationship_Own-child                48842 non-null  uint8
#  36  relationship_Unmarried                48842 non-null  uint8
#  37  relationship_Wife                     48842 non-null  uint8
#  38  race_Asian-Pac-Islander               48842 non-null  uint8
#  39  race_Black                            48842 non-null  uint8
#  40  race_Other                            48842 non-null  uint8
#  41  race_White                            48842 non-null  uint8
#  42  sex_Male                              48842 non-null  uint8
# dtypes: float64(1), int64(6), uint8(36)
# memory usage: 4.7 MB

# %% [markdown]
# # 모델링 & 평가

# %%
from sklearn.model_selection import train_test_split
X = df2.drop('class', axis=1)
y = df2['class']
X_train,X_test,y_train,y_test = train_test_split(
    X,y, test_size=0.4, random_state=100)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(random_state=100)
model.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
pred
# Out:
# array([1, 0, 0, ..., 1, 0, 1])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.8155295081128116

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=100)
model.fit(X_train,y_train) # 훈련 데이터를 통한 모델 학습
train_pred = model.predict(X_train) # 훈련 데이터로 모델을 통해서 예측한 값
test_pred = model.predict(X_test) # 시험 데이터로 모델을 통해서 예측한 값
# 문제를 풀어서 나온 답 97%
print('Train score:', accuracy_score(y_train,train_pred)) # 97%
print('Test score:', accuracy_score(y_test,test_pred)) # 81%
# Out:
# Train score: 0.9777171131206279
# Test score: 0.8155295081128116

# %%
# 깊이를 제한했더니 학습이 덜되면서 오히려 새로운 데이터에 대한 예측력 상승
model = DecisionTreeClassifier(max_depth=5, random_state=100)
model.fit(X_train,y_train)
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

print('Train score:', accuracy_score(y_train,train_pred)) # 85%
print('Test score:', accuracy_score(y_test,test_pred)) # 84.9%
# Out:
# Train score: 0.8540180856509129
# Test score: 0.8499769667809797

# %% [markdown]
# # 트리가 깊어지면 오버피팅 문제가 난다
# * 기본값(결정 트리)의 설정은 구분되는 것까지 가장 깊은 노드값까지 탐색해서 내려갑니다.
# * 오버피팅(과최적화) : 학습이 너무 잘되서 새로운 데이터에 대한 예측력이 오히려 떨어지는 상황

# %%
model = DecisionTreeClassifier(max_depth=100, random_state=100)
model.fit(X_train,y_train)
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

print('Train score:', accuracy_score(y_train,train_pred))
print('Test score:', accuracy_score(y_test,test_pred))
# Out:
# Train score: 0.9777171131206279
# Test score: 0.8155295081128116

# %%
# 위의 테스트 공식 함수화
def test_depth(depth:int):
  model = DecisionTreeClassifier(max_depth=depth, random_state=100)
  model.fit(X_train,y_train)
  train_pred = model.predict(X_train)
  test_pred = model.predict(X_test)
  print(f'**{depth}**')
  print('Train score:', accuracy_score(y_train,train_pred))
  print('Test score:', accuracy_score(y_test,test_pred))


# for in 반복문 사용해서 돌려보기
# [test_depth(d) for d in range(1,20)]
for d in range(1, 20):
  test_depth(d)
# Out:
# **1**
# Train score: 0.7619860092134448
# Test score: 0.7588166043916671
# **2**
# Train score: 0.8292100324176762
# Test score: 0.8287864052822849
# **3**
# Train score: 0.8452141272820338
# Test score: 0.8424527819010084
# **4**
# Train score: 0.8456577375874424
# Test score: 0.8428110764191022
# **5**
# Train score: 0.8540180856509129
# Test score: 0.8499769667809797
# **6**
# Train score: 0.8576010919638287
# Test score: 0.8529456927880432
# **7**
# Train score: 0.8598532673605187
# Test score: 0.8543276859292624
# **8**
# Train score: 0.8646306091110731
# Test score: 0.8556073092081691
# **9**
# Train score: 0.8684866063811636
# Test score: 0.8555049393458566
# **10**
# Train score: 0.8727520900870158
# Test score: 0.8503352612990736
# **11**
# Train score: 0.8771199454018086
# Test score: 0.8518196243026053
# **12**
# Train score: 0.8818631632827163
# Test score: 0.8502840763679173
# **13**
# Train score: 0.8876642211226753
# Test score: 0.8498234119875109
# **14**
# Train score: 0.8932264118751067
# Test score: 0.8482878640528229
# **15**
# Train score: 0.8989933458454189
# Test score: 0.8463428366688847
# **16**
# Train score: 0.9062958539498379
# Test score: 0.84352766545529
# **17**
# Train score: 0.9119945401808565
# Test score: 0.841429083277883
# **18**
# Train score: 0.9183415799351646
# Test score: 0.8394328709627885
# **19**
# Train score: 0.9246886196894728
# Test score: 0.8382044326150382

# %% [markdown]
# # 트리 그래프

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(30,15))
plot_tree(model, max_depth=3, fontsize=15)
plt.show()

# %%
plt.figure(figsize=(30,15))
plot_tree(model, max_depth= 3, fontsize=20, feature_names= X_train.columns)
plt.show()
